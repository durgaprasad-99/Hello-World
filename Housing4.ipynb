# %% [markdown]
# #Introduction
#
# In this project, we are going to use the 1990 California Census dataset to study and try to understand how the different attributes can make the house prices get higher or lower.
#
# The dataset contains the following attributes,
#
# 1.longitude: A measure of how far west a house is; a higher value is farther west
#
# 2.latitude: A measure of how far north a house is; a higher value is farther north
#
# 3.housing_median_age: Median age of a house within a block; a lower number is a newer building
#
# 4.total_rooms: Total number of rooms within a block
#
# 5.total_bedrooms: Total number of bedrooms within a block
#
# 6.population: Total number of people residing within a block
#
# 7.households: Total number of households, a group of people residing within a home unit, for a block
#
# 8.median_income: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#
# 9.ocean_proximity: Location of the house w.r.t ocean/sea
#
# 10.median_house_value: Median house value for households within a block (measured in US Dollars)
#
#
#
# latitude : continuous numerical data
#
# longitude: continuous numerical data
#
# housing_median_age: ordinal data
#
# total_rooms: Discrete data
#
#
# total_bedrooms: Discrete data
#
#
# households: Discrete data
#
# median_income: continuous numerical data
#
# ocean_proximity: Nominal data
#
# median_house_value: ordinal data

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the file 
housing = pd.read_csv("/content/housing (1).csv")
housing # print output
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.head(10) #head() shows the values of top rows, which gives more idea on data types.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
housing.tail(10)  #tail() shows the values of bottom records.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20630    -121.32     39.29                11.0       2640.0           505.0
# 20631    -121.40     39.33                15.0       2655.0           493.0
# 20632    -121.45     39.26                15.0       2319.0           416.0
# 20633    -121.53     39.19                27.0       2080.0           412.0
# 20634    -121.56     39.27                28.0       2332.0           395.0
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20630      1257.0       445.0         3.5673            112000.0
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Here, we can see that every Dtype is read correctly.

# %%
#checking for null values
housing.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# There are 207 null values in the total_bedrooms attribute.

# %%
housing.describe() # describe() shows the summmary of numerical features
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# we can see the descriptive statistics in more detailed manner.

# %%
#1.What is the average median income of the data set and check the distribution of data using appropriate plots? 
#Please explain the distribution of the plot.

housing["median_income"].mean()
# Out:
# 3.8706710029070246

# %% [markdown]
# Mean of median_income is 3.8706710029070246.

# %%
housing.hist("median_income") # plotting a histogram
plt.title("median_income") # giving the title
plt.show() #print output

# %% [markdown]
# The above histogram shows skewness towards right

# %%
#2.Draw an appropriate plot for housing_median_age and explain your observations.

sns.boxplot( y ="housing_median_age", data = housing) # boxplot from seaborn library.
plt.title("  Boxplot of housing_median_age") # giving the title
plt.xlabel("housing_median_age")
plt.show() #print output

# %%
housing["housing_median_age"].median() #   checking median value of housing_median_age attribute.
# Out:
# 29.0

# %%
housing["housing_median_age"].min()
housing["housing_median_age"].max()
# Out:
# 52.0

# %% [markdown]
# The above boxplot shows that there are no outliers in the housing_median_age attribute.
# The median value of housing_median_age is 29.0, and its lower limit value is 1.0 and upper limit value is 52.0

# %%
#3.Show with the help of visualization, how median_income and median_house_values are related?

plt.figure(figsize=(10,8)) #   giving the figure size
sns.scatterplot(data=housing, x='median_income', y='median_house_value', alpha=0.4)
plt.title("Relationship between median_income and median_house_value") # giving the title
plt.show() #print output

# %% [markdown]
# The upward trend between the median_income and median_house_value indicates a strong correlation.
# House value increases with increase in income. An increase in income creates an opportunity to access higher value houses.

# %%
#4.Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

housing_1= housing.drop(["longitude","latitude","ocean_proximity","median_income"], axis = 1) # dropping the features. 
housing_1 #
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_house_value
# 0           126.0            452600.0
# 1          1138.0            358500.0
# 2           177.0            352100.0
# ...

# %%
#5.Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# There are 207 missing values in total_bedrooms.Filling the missing values with the mean of total_bedrooms.

df = housing["total_bedrooms"].mean() 
df
# Out:
# 537.8705525375639

# %% [markdown]
# Mean of total_bedrooms is 537.8705525375618

# %%
df=housing.fillna(537.8705525375618,inplace = True)
df

# %% [markdown]
# Filling the null values with 537.8705525375618 in the total_bedrooms column.

# %%
df =housing.isnull().sum() 
df
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# Now,we can see that there are no missing or null values.

# %%
#6.Plot latitude versus longitude and explain your observations.

housing.plot(kind = 'scatter',x = 'longitude',y = 'latitude',alpha = 0.5, s = housing['population']/50,
label = 'population', c = 'median_house_value',cmap = 'jet',colorbar = True,figsize = (10,8))
plt.xlabel("longitude")
plt.ylabel("latitude") # giving y label
plt.show() # print output

# %% [markdown]
# The graph shows house prices in California where red is expensive, blue is less expensive, larger circles indicate areas with a larger population.

# %%
#7.Create a data set for which the ocean_proximity is Near the ocean.

housing["ocean_proximity"].value_counts() # value counts of ocean_proximity
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# <1H OCEAN values_counts are 9136,  INLAND 6551,  NEAR OCEAN 2658,  NEAR BAY 2290,  and  ISLAND values are 5.

# %%
nearbay_housing = housing.loc[housing['ocean_proximity'] == 'NEAR BAY']
nearbay_housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %% [markdown]
# Here, we are using loc function,it is a selecting method we can give the name of a  row or column.So,here taking the row value which is NEAR BAY.

# %%
#8.Find the mean and median of the median income for the data set created in question 8.
nearbay_housing["median_income"].mean()
# Out:
# 4.172884759825336

# %% [markdown]
# Mean of median_income in the newly created dataset nearbay_housing is 4.172884759825336

# %%
nearbay_housing["median_income"].median()
# Out:
# 3.81865

# %% [markdown]
# Median of median_income in the newly created dataset nearbay_housing is 3.81865

# %%
#9.Please create a new column named total_bedroom_size. If size 10 or less. It should be quoted as small. 
#If the size is 11 or more but 1000 less, it should be medium, otherwise, it should be large.

total_bedroom_size= []   # creating a new column
for value in housing["total_bedrooms"]:
    if value <= 10:
        total_bedroom_size.append("small")
    elif value > 11 and value < 1000:
        total_bedroom_size.append("medium")
    else:
        total_bedroom_size.append("large")
       
housing["total_bedroom_size"] = total_bedroom_size 
print(housing) # print out
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
#  Using looping condition ,The new column "total_bedroom_size" is created with values small,medium and large in it w.r.t size.

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   total_bedroom_size
# 0             medium
# 1              large
# ...
